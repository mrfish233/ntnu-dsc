# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("world-population.csv")
df = pd.DataFrame(data)
df[df[].notnull()]
# Out:
#     Year (July 1)  Population Yearly % Change  Yearly Change  Median Age  \
# 0            2023  8045311447           0.88%       70206291        30.5
# 1            2022  7975105156           0.83%       65810005        30.2
# 2            2021  7909295151           0.87%       68342271        30.0
# 3            2020  7840952880           0.98%       76001848        29.7
# 4            2015  7426597537           1.23%       88198886        28.0
# 5            2010  6985603105           1.27%       85485397        27.0
# 6            2005  6558176119           1.30%       81855429        26.0
# 7            2000  6148898975           1.37%       81135904        25.0
# 8            1995  5743219454           1.56%       85408718        24.0
# 9            1990  5316175862           1.80%       90889050        23.0
# 10           1985  4861730613           1.81%       83544581        22.0
# 11           1980  4444007706           1.78%       74914095        22.0
# ...

# %%
x = df['Year (July 1)']
y = df['Median Age']
df.plot(x='Year (July 1)', y='Median Age', xlabel='Year', ylabel='Age')
# Out:
# <Axes: xlabel='Year', ylabel='Age'>

# %%
data2 = pd.read_csv("hinanjo_20240401.csv",encoding='shift-jis')
data2
# Out:
#       NO             名称  名称_かな  名称_カナ                  住所  方書      郵便番号  \
# 0      1  波多江コミュニティセンター    NaN    NaN       福岡県糸島市池田216-1 NaN  819 1103
# 1      2    波多江小学校グラウンド    NaN    NaN  福岡県糸島市波多江駅北四丁目12-1 NaN  819 1107
# 2      3    波多江コミュニティ広場    NaN    NaN       福岡県糸島市池田214-1 NaN  819 1103
# 3      4          高田東公園    NaN    NaN       福岡県糸島市高田四丁目17 NaN  819 1102
# 4      5  東風コミュニティセンター     NaN    NaN      福岡県糸島市潤四丁目10-2 NaN  819 1105
# ..   ...            ...    ...    ...                 ...  ..       ...
# 114  115          志摩中学校    NaN    NaN   福岡県糸島市志摩小金丸1836-1 NaN  819 1323
# 115  116          桜野小学校    NaN    NaN      福岡県糸島市志摩桜井5921 NaN  819 1304
# 116  117          引津小学校    NaN    NaN    福岡県糸島市志摩御床2165-2 NaN  819 1322
# 117  118          姫島小学校    NaN    NaN     福岡県糸島市志摩姫島976-3 NaN  819 1336
# 118  119      志摩中学校姫島分校    NaN    NaN     福岡県糸島市志摩姫島976-3 NaN  819 1336
#
#             緯度          経度  標高  ... 指定避難所との重複  炊はん能力  想定収容人数  対象となる町会・自治会  \
# ...

# %%
data2['電話番号']
