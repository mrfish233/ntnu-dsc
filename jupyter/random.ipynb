# %%
import pandas as pd
import random, time
random.seed(time.time())

# %%
# choices = ['apple', 'banana', 'cherry', 'date']
# list = [random.randint(0, 100) for i in range(samples)]
# list = [random.uniform(0, 1) for i in range(samples)]
# list = [random.choice(choices) for i in range(samples)]

# %%
samples = 10000
mean_val = 160
std_dev = 10

# %%
list = [random.gauss(mean, std_dev) for i in range(samples)]
data = pd.Series(list)
data.hist(bins=100)
# Out:
# <Axes: >

# %%
height_mean = 160
height_stddev = 10
weight_mean = 50
weight_stddev = 5

# %%
id = [i for i in range(samples)]
height_list = [random.gauss(height_mean, height_stddev) for _ in range(samples)]
weight_list = [random.gauss(weight_mean, weight_stddev) for _ in range(samples)]

df = pd.DataFrame({'id': id, 'height': height_list, 'weight': weight_list})
df.plot.scatter('height', 'weight', alpha=0.2)
# Out:
# <Axes: xlabel='height', ylabel='weight'>

# %%
num_samples = 100
lat_mean = 24
lat_sd = 1
lon_mean = 121
lon_sd = 1
temp_mean = 32
temp_sd = 2
# lat_min = 22
# lat_max = 24
# lon_min = 120
# lon_max = 122
# tmp_min = 30
# tmp_max = 35

# %%
id = [i for i in range(num_samples)]
lat_list = [random.gauss(lat_mean, lat_sd) for _ in range(num_samples)]
lon_list = [random.gauss(lon_mean, lon_sd) for _ in range(num_samples)]
temp_list = [random.gauss(temp_mean, temp_sd) for _ in range(num_samples)]
# lat_list = [random.uniform(lat_min, lat_max) for _ in range(num_samples)]
# lon_list = [random.uniform(lon_min, lon_max) for _ in range(num_samples)]
# tmp_list = [random.uniform(tmp_min, tmp_max) for _ in range(num_samples)]

temp_df = pd.DataFrame({'id': id, 'lat_list': lat_list, 'lon_list': lon_list, 'temp_list': temp_list})
temp_df.plot.scatter(x='lat_list', y='lon_list', c='temp_list', xlabel='Latitude', ylabel='Longitude')
# Out:
# <Axes: xlabel='Latitude', ylabel='Longitude'>
